# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 627

# %%
import requests

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("---------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | terrace
# Processing Record 2 of Set 1 | zabid
# Processing Record 3 of Set 1 | faanui
# Processing Record 4 of Set 1 | kapaa
# Processing Record 5 of Set 1 | khatanga
# Processing Record 6 of Set 1 | russell
# Processing Record 7 of Set 1 | lorain
# Processing Record 8 of Set 1 | bluff
# Processing Record 9 of Set 1 | kovdor
# Processing Record 10 of Set 1 | hilo
# Processing Record 11 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 1 | saint-philippe
# Processing Record 13 of Set 1 | gulshat
# City not found. Skipping...
# Processing Record 14 of Set 1 | buala
# Processing Record 15 of Set 1 | yulara
# Processing Record 16 of Set 1 | bougouni
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 1 | houston
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | touros
# Processing Record 22 of Set 1 | saint-pierre
# Processing Record 23 of Set 1 | nadym
# Processing Record 24 of Set 1 | klaksvik
# Processing Record 25 of Set 1 | caucaia
# Processing Record 26 of Set 1 | lorengau
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | provideniya
# Processing Record 29 of Set 1 | rikitea
# Processing Record 30 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 1 | acapulco
# Processing Record 32 of Set 1 | tsentralnyy
# City not found. Skipping...
# Processing Record 33 of Set 1 | busselton
# Processing Record 34 of Set 1 | cabedelo
# Processing Record 35 of Set 1 | georgetown
# Processing Record 36 of Set 1 | arraial do cabo
# Processing Record 37 of Set 1 | sambava
# Processing Record 38 of Set 1 | jingdezhen
# Processing Record 39 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 1 | atuona
# Processing Record 41 of Set 1 | merrill
# Processing Record 42 of Set 1 | vaini
# Processing Record 43 of Set 1 | killybegs
# Processing Record 44 of Set 1 | kahului
# Processing Record 45 of Set 1 | cape town
# Processing Record 46 of Set 1 | hermanus
# Processing Record 47 of Set 1 | gamba
# Processing Record 48 of Set 1 | tuatapere
# Processing Record 49 of Set 1 | ihosy
# Processing Record 50 of Set 1 | jamestown
# Processing Record 1 of Set 2 | roald
# Processing Record 2 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 2 | bambous virieux
# Processing Record 4 of Set 2 | opuwo
# Processing Record 5 of Set 2 | ribeira grande
# Processing Record 6 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 2 | sao joaquim
# Processing Record 8 of Set 2 | pontianak
# Processing Record 9 of Set 2 | sibolga
# Processing Record 10 of Set 2 | tabialan
# City not found. Skipping...
# Processing Record 11 of Set 2 | kieta
# Processing Record 12 of Set 2 | port hueneme
# Processing Record 13 of Set 2 | tasiilaq
# Processing Record 14 of Set 2 | albany
# Processing Record 15 of Set 2 | yellowknife
# Processing Record 16 of Set 2 | san policarpo
# Processing Record 17 of Set 2 | atherton
# Processing Record 18 of Set 2 | bredasdorp
# Processing Record 19 of Set 2 | hobart
# Processing Record 20 of Set 2 | zhanatas
# City not found. Skipping...
# Processing Record 21 of Set 2 | adrar
# Processing Record 22 of Set 2 | castro
# Processing Record 23 of Set 2 | kaitangata
# Processing Record 24 of Set 2 | erzin
# Processing Record 25 of Set 2 | karkaralinsk
# City not found. Skipping...
# Processing Record 26 of Set 2 | avarua
# Processing Record 27 of Set 2 | mangrol
# Processing Record 28 of Set 2 | westport
# Processing Record 29 of Set 2 | batemans bay
# Processing Record 30 of Set 2 | orzhytsya
# Processing Record 31 of Set 2 | mayo
# Processing Record 32 of Set 2 | chokurdakh
# Processing Record 33 of Set 2 | lebu
# Processing Record 34 of Set 2 | menongue
# Processing Record 35 of Set 2 | butaritari
# Processing Record 36 of Set 2 | ucluelet
# Processing Record 37 of Set 2 | vestmannaeyjar
# Processing Record 38 of Set 2 | yarmouth
# Processing Record 39 of Set 2 | nouadhibou
# Processing Record 40 of Set 2 | east london
# Processing Record 41 of Set 2 | iqaluit
# Processing Record 42 of Set 2 | torbay
# Processing Record 43 of Set 2 | mayumba
# Processing Record 44 of Set 2 | sabang
# Processing Record 45 of Set 2 | huntsville
# Processing Record 46 of Set 2 | tuktoyaktuk
# Processing Record 47 of Set 2 | pizarro
# Processing Record 48 of Set 2 | chuy
# Processing Record 49 of Set 2 | sangueya
# Processing Record 50 of Set 2 | barrow
# Processing Record 1 of Set 3 | upernavik
# Processing Record 2 of Set 3 | rangapara
# Processing Record 3 of Set 3 | luderitz
# Processing Record 4 of Set 3 | ouango
# Processing Record 5 of Set 3 | saint-louis
# Processing Record 6 of Set 3 | lillooet
# Processing Record 7 of Set 3 | dikson
# Processing Record 8 of Set 3 | isangel
# Processing Record 9 of Set 3 | mar del plata
# Processing Record 10 of Set 3 | belaya gora
# Processing Record 11 of Set 3 | khuzdar
# Processing Record 12 of Set 3 | hithadhoo
# Processing Record 13 of Set 3 | cockburn town
# Processing Record 14 of Set 3 | calais
# Processing Record 15 of Set 3 | fortuna
# Processing Record 16 of Set 3 | aklavik
# Processing Record 17 of Set 3 | belyy yar
# Processing Record 18 of Set 3 | puerto escondido
# Processing Record 19 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 3 | athabasca
# Processing Record 21 of Set 3 | acari
# Processing Record 22 of Set 3 | shakawe
# Processing Record 23 of Set 3 | kloulklubed
# Processing Record 24 of Set 3 | nhulunbuy
# Processing Record 25 of Set 3 | amurzet
# Processing Record 26 of Set 3 | fairbanks
# Processing Record 27 of Set 3 | severo-kurilsk
# Processing Record 28 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 3 | kruisfontein
# Processing Record 30 of Set 3 | narsaq
# Processing Record 31 of Set 3 | nevelsk
# Processing Record 32 of Set 3 | maceio
# Processing Record 33 of Set 3 | marsh harbour
# Processing Record 34 of Set 3 | saldanha
# Processing Record 35 of Set 3 | dillon
# Processing Record 36 of Set 3 | urumqi
# Processing Record 37 of Set 3 | czestochowa
# Processing Record 38 of Set 3 | cacule
# Processing Record 39 of Set 3 | hamilton
# Processing Record 40 of Set 3 | new norfolk
# Processing Record 41 of Set 3 | sinnamary
# Processing Record 42 of Set 3 | merauke
# Processing Record 43 of Set 3 | arkhipo-osipovka
# Processing Record 44 of Set 3 | kodiak
# Processing Record 45 of Set 3 | gunjur
# Processing Record 46 of Set 3 | lavrentiya
# Processing Record 47 of Set 3 | shenjiamen
# Processing Record 48 of Set 3 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 49 of Set 3 | sirpur
# Processing Record 50 of Set 3 | qaanaaq
# Processing Record 1 of Set 4 | juneau
# Processing Record 2 of Set 4 | beidao
# Processing Record 3 of Set 4 | taoudenni
# Processing Record 4 of Set 4 | koumac
# Processing Record 5 of Set 4 | muros
# Processing Record 6 of Set 4 | thompson
# Processing Record 7 of Set 4 | mahebourg
# Processing Record 8 of Set 4 | sarangani
# Processing Record 9 of Set 4 | harwich
# Processing Record 10 of Set 4 | mount isa
# Processing Record 11 of Set 4 | urusha
# Processing Record 12 of Set 4 | samarai
# Processing Record 13 of Set 4 | gurskoye
# City not found. Skipping...
# Processing Record 14 of Set 4 | igarka
# Processing Record 15 of Set 4 | tautira
# Processing Record 16 of Set 4 | bengkulu
# Processing Record 17 of Set 4 | paracuru
# Processing Record 18 of Set 4 | asau
# Processing Record 19 of Set 4 | kutum
# Processing Record 20 of Set 4 | saint anthony
# Processing Record 21 of Set 4 | puerto ayora
# Processing Record 22 of Set 4 | kisangani
# Processing Record 23 of Set 4 | anadyr
# Processing Record 24 of Set 4 | dwarka
# Processing Record 25 of Set 4 | paamiut
# Processing Record 26 of Set 4 | longlac
# City not found. Skipping...
# Processing Record 27 of Set 4 | nelson bay
# Processing Record 28 of Set 4 | dunedin
# Processing Record 29 of Set 4 | la palma
# Processing Record 30 of Set 4 | carnarvon
# Processing Record 31 of Set 4 | ponta do sol
# Processing Record 32 of Set 4 | saskylakh
# Processing Record 33 of Set 4 | meulaboh
# Processing Record 34 of Set 4 | port alfred
# Processing Record 35 of Set 4 | coahuayana
# Processing Record 36 of Set 4 | galautas
# Processing Record 37 of Set 4 | tulum
# Processing Record 38 of Set 4 | brindisi
# Processing Record 39 of Set 4 | sao filipe
# Processing Record 40 of Set 4 | berdigestyakh
# Processing Record 41 of Set 4 | sept-iles
# Processing Record 42 of Set 4 | wulanhaote
# City not found. Skipping...
# Processing Record 43 of Set 4 | dalbandin
# Processing Record 44 of Set 4 | tarsus
# Processing Record 45 of Set 4 | silyanah
# City not found. Skipping...
# Processing Record 46 of Set 4 | pevek
# Processing Record 47 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 4 | pirassununga
# Processing Record 49 of Set 4 | formosa do rio preto
# Processing Record 50 of Set 4 | praia da vitoria
# Processing Record 1 of Set 5 | airai
# Processing Record 2 of Set 5 | port-gentil
# Processing Record 3 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 4 of Set 5 | port hardy
# Processing Record 5 of Set 5 | karratha
# Processing Record 6 of Set 5 | tommot
# Processing Record 7 of Set 5 | miraflores
# Processing Record 8 of Set 5 | guerrero negro
# Processing Record 9 of Set 5 | norman wells
# Processing Record 10 of Set 5 | shimoda
# Processing Record 11 of Set 5 | kisanga
# Processing Record 12 of Set 5 | belmonte
# Processing Record 13 of Set 5 | novyy urengoy
# Processing Record 14 of Set 5 | arawa
# Processing Record 15 of Set 5 | marawi
# Processing Record 16 of Set 5 | souillac
# Processing Record 17 of Set 5 | quatre cocos
# Processing Record 18 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 5 | les cayes
# Processing Record 20 of Set 5 | chifeng
# Processing Record 21 of Set 5 | sancti spiritus
# Processing Record 22 of Set 5 | salalah
# Processing Record 23 of Set 5 | kysyl-syr
# Processing Record 24 of Set 5 | myatlevo
# Processing Record 25 of Set 5 | labrea
# Processing Record 26 of Set 5 | sao joao da barra
# Processing Record 27 of Set 5 | grigiskes
# Processing Record 28 of Set 5 | flinders
# Processing Record 29 of Set 5 | baijiantan
# Processing Record 30 of Set 5 | newport
# Processing Record 31 of Set 5 | tiksi
# Processing Record 32 of Set 5 | kalengwa
# Processing Record 33 of Set 5 | sola
# Processing Record 34 of Set 5 | buchanan
# Processing Record 35 of Set 5 | nabire
# Processing Record 36 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 5 | port moresby
# Processing Record 38 of Set 5 | mount gambier
# Processing Record 39 of Set 5 | caravelas
# Processing Record 40 of Set 5 | esperance
# Processing Record 41 of Set 5 | novikovo
# Processing Record 42 of Set 5 | vrangel
# Processing Record 43 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 5 | nome
# Processing Record 45 of Set 5 | youghal
# Processing Record 46 of Set 5 | sioux lookout
# Processing Record 47 of Set 5 | yining
# Processing Record 48 of Set 5 | comodoro rivadavia
# Processing Record 49 of Set 5 | bonavista
# Processing Record 50 of Set 5 | eydhafushi
# Processing Record 1 of Set 6 | nemuro
# Processing Record 2 of Set 6 | vanimo
# Processing Record 3 of Set 6 | brae
# Processing Record 4 of Set 6 | shuangyang
# Processing Record 5 of Set 6 | alta floresta
# Processing Record 6 of Set 6 | senahu
# Processing Record 7 of Set 6 | makakilo city
# Processing Record 8 of Set 6 | conceicao da barra
# Processing Record 9 of Set 6 | guanare
# Processing Record 10 of Set 6 | karatuzskoye
# Processing Record 11 of Set 6 | port lincoln
# Processing Record 12 of Set 6 | lasa
# Processing Record 13 of Set 6 | ust-maya
# Processing Record 14 of Set 6 | vao
# Processing Record 15 of Set 6 | minab
# Processing Record 16 of Set 6 | gat
# Processing Record 17 of Set 6 | akyab
# Processing Record 18 of Set 6 | ballina
# Processing Record 19 of Set 6 | hauterive
# Processing Record 20 of Set 6 | katsuura
# Processing Record 21 of Set 6 | pringsewu
# Processing Record 22 of Set 6 | tura
# Processing Record 23 of Set 6 | serenje
# Processing Record 24 of Set 6 | nishihara
# Processing Record 25 of Set 6 | morehead
# Processing Record 26 of Set 6 | namatanai
# Processing Record 27 of Set 6 | ponta delgada
# Processing Record 28 of Set 6 | mizdah
# Processing Record 29 of Set 6 | mackay
# Processing Record 30 of Set 6 | amapa
# Processing Record 31 of Set 6 | puri
# Processing Record 32 of Set 6 | ilulissat
# Processing Record 33 of Set 6 | maniitsoq
# Processing Record 34 of Set 6 | nanortalik
# Processing Record 35 of Set 6 | galle
# Processing Record 36 of Set 6 | longyearbyen
# Processing Record 37 of Set 6 | zeya
# Processing Record 38 of Set 6 | gardan diwal
# City not found. Skipping...
# Processing Record 39 of Set 6 | takoradi
# Processing Record 40 of Set 6 | hovd
# Processing Record 41 of Set 6 | acarau
# Processing Record 42 of Set 6 | san cristobal
# Processing Record 43 of Set 6 | barbastro
# Processing Record 44 of Set 6 | luwuk
# Processing Record 45 of Set 6 | bose
# Processing Record 46 of Set 6 | siyabuswa
# Processing Record 47 of Set 6 | canela
# Processing Record 48 of Set 6 | severodvinsk
# Processing Record 49 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 6 | sussex
# Processing Record 1 of Set 7 | bom jesus
# Processing Record 2 of Set 7 | rawson
# Processing Record 3 of Set 7 | pisco
# Processing Record 4 of Set 7 | dawei
# Processing Record 5 of Set 7 | kigorobya
# Processing Record 6 of Set 7 | bay roberts
# Processing Record 7 of Set 7 | turka
# Processing Record 8 of Set 7 | chapais
# Processing Record 9 of Set 7 | paka
# Processing Record 10 of Set 7 | soritor
# Processing Record 11 of Set 7 | victoria
# Processing Record 12 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 7 | hasaki
# Processing Record 14 of Set 7 | inhambane
# Processing Record 15 of Set 7 | caramay
# Processing Record 16 of Set 7 | kula
# Processing Record 17 of Set 7 | pacific grove
# Processing Record 18 of Set 7 | turukhansk
# Processing Record 19 of Set 7 | amot
# Processing Record 20 of Set 7 | taltal
# Processing Record 21 of Set 7 | lagoa
# Processing Record 22 of Set 7 | greensburg
# Processing Record 23 of Set 7 | baykit
# Processing Record 24 of Set 7 | novobirilyussy
# Processing Record 25 of Set 7 | akdepe
# Processing Record 26 of Set 7 | independencia
# Processing Record 27 of Set 7 | dingle
# Processing Record 28 of Set 7 | luau
# Processing Record 29 of Set 7 | vardo
# Processing Record 30 of Set 7 | road town
# Processing Record 31 of Set 7 | christchurch
# Processing Record 32 of Set 7 | kontagora
# Processing Record 33 of Set 7 | coihaique
# Processing Record 34 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 7 | codrington
# Processing Record 36 of Set 7 | lompoc
# Processing Record 37 of Set 7 | korla
# Processing Record 38 of Set 7 | skalistyy
# City not found. Skipping...
# Processing Record 39 of Set 7 | luanda
# Processing Record 40 of Set 7 | araouane
# Processing Record 41 of Set 7 | manokwari
# Processing Record 42 of Set 7 | burnie
# Processing Record 43 of Set 7 | los llanos de aridane
# Processing Record 44 of Set 7 | voyvozh
# Processing Record 45 of Set 7 | marsa matruh
# Processing Record 46 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 47 of Set 7 | mastic beach
# Processing Record 48 of Set 7 | koslan
# Processing Record 49 of Set 7 | galesong
# Processing Record 50 of Set 7 | singapore
# Processing Record 1 of Set 8 | santa rosa
# Processing Record 2 of Set 8 | kimbe
# Processing Record 3 of Set 8 | mwinilunga
# Processing Record 4 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 5 of Set 8 | port elizabeth
# Processing Record 6 of Set 8 | kampen
# Processing Record 7 of Set 8 | mahibadhoo
# Processing Record 8 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 9 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 10 of Set 8 | ishigaki
# Processing Record 11 of Set 8 | wanaka
# Processing Record 12 of Set 8 | mildura
# Processing Record 13 of Set 8 | bhan
# Processing Record 14 of Set 8 | colesberg
# Processing Record 15 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 16 of Set 8 | kuching
# Processing Record 17 of Set 8 | santa pola
# Processing Record 18 of Set 8 | ukiah
# Processing Record 19 of Set 8 | kalmunai
# Processing Record 20 of Set 8 | selikhino
# Processing Record 21 of Set 8 | rantepao
# Processing Record 22 of Set 8 | candawaga
# City not found. Skipping...
# Processing Record 23 of Set 8 | qasigiannguit
# Processing Record 24 of Set 8 | kavaratti
# Processing Record 25 of Set 8 | itarema
# Processing Record 26 of Set 8 | wahran
# City not found. Skipping...
# Processing Record 27 of Set 8 | sorland
# Processing Record 28 of Set 8 | berlevag
# Processing Record 29 of Set 8 | terrace bay
# Processing Record 30 of Set 8 | ketchikan
# Processing Record 31 of Set 8 | manaus
# Processing Record 32 of Set 8 | honiara
# Processing Record 33 of Set 8 | nikolskoye
# Processing Record 34 of Set 8 | adlay
# Processing Record 35 of Set 8 | kodinar
# Processing Record 36 of Set 8 | kristiinankaupunki
# Processing Record 37 of Set 8 | damietta
# Processing Record 38 of Set 8 | shipunovo
# Processing Record 39 of Set 8 | half moon bay
# Processing Record 40 of Set 8 | vaijapur
# Processing Record 41 of Set 8 | batagay
# Processing Record 42 of Set 8 | shiozawa
# Processing Record 43 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 44 of Set 8 | bekhtery
# Processing Record 45 of Set 8 | ambon
# Processing Record 46 of Set 8 | labytnangi
# Processing Record 47 of Set 8 | vila do maio
# Processing Record 48 of Set 8 | pangkalanbuun
# Processing Record 49 of Set 8 | plettenberg bay
# Processing Record 50 of Set 8 | geraldton
# Processing Record 1 of Set 9 | ancud
# Processing Record 2 of Set 9 | cabo san lucas
# Processing Record 3 of Set 9 | yuncheng
# Processing Record 4 of Set 9 | carlsbad
# Processing Record 5 of Set 9 | uhlove
# Processing Record 6 of Set 9 | westpunt
# City not found. Skipping...
# Processing Record 7 of Set 9 | kismayo
# Processing Record 8 of Set 9 | plouzane
# Processing Record 9 of Set 9 | solnechnyy
# Processing Record 10 of Set 9 | pierre
# Processing Record 11 of Set 9 | andevoranto
# City not found. Skipping...
# Processing Record 12 of Set 9 | hobyo
# Processing Record 13 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 14 of Set 9 | kyabe
# Processing Record 15 of Set 9 | seoul
# Processing Record 16 of Set 9 | jiayuguan
# Processing Record 17 of Set 9 | zhanakorgan
# Processing Record 18 of Set 9 | guanica
# Processing Record 19 of Set 9 | san andres
# Processing Record 20 of Set 9 | la rioja
# Processing Record 21 of Set 9 | vung tau
# Processing Record 22 of Set 9 | ostrovnoy
# Processing Record 23 of Set 9 | winsum
# Processing Record 24 of Set 9 | cidreira
# Processing Record 25 of Set 9 | olafsvik
# Processing Record 26 of Set 9 | sandwick
# Processing Record 27 of Set 9 | tingrela
# City not found. Skipping...
# Processing Record 28 of Set 9 | lushunkou
# City not found. Skipping...
# Processing Record 29 of Set 9 | eureka
# Processing Record 30 of Set 9 | bontang
# Processing Record 31 of Set 9 | rosetta
# Processing Record 32 of Set 9 | oriximina
# Processing Record 33 of Set 9 | agirish
# Processing Record 34 of Set 9 | tecoanapa
# Processing Record 35 of Set 9 | khavarion
# City not found. Skipping...
# Processing Record 36 of Set 9 | grindavik
# Processing Record 37 of Set 9 | liuzhou
# Processing Record 38 of Set 9 | ekhabi
# Processing Record 39 of Set 9 | port hedland
# Processing Record 40 of Set 9 | azimur
# City not found. Skipping...
# Processing Record 41 of Set 9 | montrose
# Processing Record 42 of Set 9 | adre
# Processing Record 43 of Set 9 | margate
# Processing Record 44 of Set 9 | shingu
# Processing Record 45 of Set 9 | dudinka
# Processing Record 46 of Set 9 | matadi
# Processing Record 47 of Set 9 | flin flon
# Processing Record 48 of Set 9 | katrineholm
# Processing Record 49 of Set 9 | bethel
# Processing Record 50 of Set 9 | zheleznodorozhnyy
# Processing Record 1 of Set 10 | tiznit
# Processing Record 2 of Set 10 | bari
# Processing Record 3 of Set 10 | thinadhoo
# Processing Record 4 of Set 10 | santa cruz
# Processing Record 5 of Set 10 | bashtanka
# Processing Record 6 of Set 10 | hualmay
# Processing Record 7 of Set 10 | mabaruma
# Processing Record 8 of Set 10 | taywarah
# Processing Record 9 of Set 10 | riyadh
# Processing Record 10 of Set 10 | aras
# Processing Record 11 of Set 10 | ugoofaaru
# Processing Record 12 of Set 10 | alamogordo
# Processing Record 13 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 14 of Set 10 | nichinan
# Processing Record 15 of Set 10 | srednekolymsk
# Processing Record 16 of Set 10 | antofagasta
# Processing Record 17 of Set 10 | pangnirtung
# Processing Record 18 of Set 10 | longkou
# Processing Record 19 of Set 10 | aswan
# Processing Record 20 of Set 10 | chilca
# Processing Record 21 of Set 10 | mutsamudu
# City not found. Skipping...
# Processing Record 22 of Set 10 | cayenne
# Processing Record 23 of Set 10 | makueni
# Processing Record 24 of Set 10 | netrakona
# Processing Record 25 of Set 10 | carberry
# Processing Record 26 of Set 10 | lubao
# Processing Record 27 of Set 10 | kosonsoy
# Processing Record 28 of Set 10 | bend
# Processing Record 29 of Set 10 | tulancingo
# Processing Record 30 of Set 10 | poindimie
# Processing Record 31 of Set 10 | port blair
# Processing Record 32 of Set 10 | ntchisi
# Processing Record 33 of Set 10 | talnakh
# Processing Record 34 of Set 10 | kavieng
# Processing Record 35 of Set 10 | mehamn
# Processing Record 36 of Set 10 | tigil
# Processing Record 37 of Set 10 | fangshan
# Processing Record 38 of Set 10 | urengoy
# Processing Record 39 of Set 10 | atar
# Processing Record 40 of Set 10 | angoche
# Processing Record 41 of Set 10 | oranjemund
# Processing Record 42 of Set 10 | sitka
# Processing Record 43 of Set 10 | yeppoon
# Processing Record 44 of Set 10 | inuvik
# Processing Record 45 of Set 10 | kamennogorsk
# Processing Record 46 of Set 10 | listvyanka
# Processing Record 47 of Set 10 | guilin
# Processing Record 48 of Set 10 | ayer itam
# City not found. Skipping...
# Processing Record 49 of Set 10 | fukue
# Processing Record 50 of Set 10 | sangar
# Processing Record 1 of Set 11 | istok
# Processing Record 2 of Set 11 | san patricio
# Processing Record 3 of Set 11 | hargeysa
# Processing Record 4 of Set 11 | fare
# Processing Record 5 of Set 11 | baie-comeau
# Processing Record 6 of Set 11 | cumanayagua
# Processing Record 7 of Set 11 | burns lake
# Processing Record 8 of Set 11 | te anau
# Processing Record 9 of Set 11 | jibuti
# Processing Record 10 of Set 11 | varzelandia
# Processing Record 11 of Set 11 | maldonado
# Processing Record 12 of Set 11 | sumbe
# Processing Record 13 of Set 11 | boden
# Processing Record 14 of Set 11 | saint-joseph
# Processing Record 15 of Set 11 | brunico
# Processing Record 16 of Set 11 | kozhva
# Processing Record 17 of Set 11 | abaete
# Processing Record 18 of Set 11 | nanzhang
# Processing Record 19 of Set 11 | turinsk
# Processing Record 20 of Set 11 | naze
# Processing Record 21 of Set 11 | ranong
# Processing Record 22 of Set 11 | tucuma
# Processing Record 23 of Set 11 | jasper
# Processing Record 24 of Set 11 | kumylzhenskaya
# Processing Record 25 of Set 11 | umm kaddadah
# Processing Record 26 of Set 11 | saint-augustin
# Processing Record 27 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 28 of Set 11 | ahipara
# Processing Record 29 of Set 11 | talcahuano
# Processing Record 30 of Set 11 | saint george
# Processing Record 31 of Set 11 | vilhena
# Processing Record 32 of Set 11 | clyde river
# Processing Record 33 of Set 11 | manuk mangkaw
# Processing Record 34 of Set 11 | shahrud
# Processing Record 35 of Set 11 | ca mau
# Processing Record 36 of Set 11 | babanusah
# City not found. Skipping...
# Processing Record 37 of Set 11 | pauini
# Processing Record 38 of Set 11 | hvolsvollur
# Processing Record 39 of Set 11 | bathsheba
# Processing Record 40 of Set 11 | biltine
# Processing Record 41 of Set 11 | tutoia
# Processing Record 42 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 43 of Set 11 | oistins
# Processing Record 44 of Set 11 | whitehorse
# Processing Record 45 of Set 11 | haines junction
# Processing Record 46 of Set 11 | floresti
# Processing Record 47 of Set 11 | southaven
# Processing Record 48 of Set 11 | bredy
# Processing Record 49 of Set 11 | moose factory
# Processing Record 50 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 1 of Set 12 | katobu
# Processing Record 2 of Set 12 | jiroft
# City not found. Skipping...
# Processing Record 3 of Set 12 | sao jose da coroa grande
# Processing Record 4 of Set 12 | phuket
# Processing Record 5 of Set 12 | san francisco
# Processing Record 6 of Set 12 | eldorado
# Processing Record 7 of Set 12 | parakou
# Processing Record 8 of Set 12 | winnemucca
# Processing Record 9 of Set 12 | hofn
# Processing Record 10 of Set 12 | papar
# Processing Record 11 of Set 12 | latung
# Processing Record 12 of Set 12 | pochutla
# Processing Record 13 of Set 12 | parnamirim
# Processing Record 14 of Set 12 | peleduy
# Processing Record 15 of Set 12 | emerald
# Processing Record 16 of Set 12 | mackenzie
# Processing Record 17 of Set 12 | sharjah
# Processing Record 18 of Set 12 | kaliwungu
# Processing Record 19 of Set 12 | prabumulih
# Processing Record 20 of Set 12 | kyshtovka
# Processing Record 21 of Set 12 | sidi ali
# Processing Record 22 of Set 12 | beisfjord
# Processing Record 23 of Set 12 | rocha
# Processing Record 24 of Set 12 | padang
# Processing Record 25 of Set 12 | manggar
# Processing Record 26 of Set 12 | lira
# Processing Record 27 of Set 12 | kwekwe
# Processing Record 28 of Set 12 | broome
# Processing Record 29 of Set 12 | portsmouth
# Processing Record 30 of Set 12 | kudahuvadhoo
# Processing Record 31 of Set 12 | avenal
# Processing Record 32 of Set 12 | faya
# Processing Record 33 of Set 12 | lisakovsk
# Processing Record 34 of Set 12 | poum
# Processing Record 35 of Set 12 | chaumont
# Processing Record 36 of Set 12 | bethlehem
# Processing Record 37 of Set 12 | bintulu
# Processing Record 38 of Set 12 | nantucket
# Processing Record 39 of Set 12 | presidencia roque saenz pena
# Processing Record 40 of Set 12 | palmer
# Processing Record 41 of Set 12 | tateyama
# Processing Record 42 of Set 12 | bauchi
# Processing Record 43 of Set 12 | saint-francois
# Processing Record 44 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 45 of Set 12 | omboue
# Processing Record 46 of Set 12 | priiskovyy
# Processing Record 47 of Set 12 | zyryanka
# Processing Record 48 of Set 12 | moerai
# Processing Record 49 of Set 12 | luena
# Processing Record 50 of Set 12 | shelburne
# Processing Record 1 of Set 13 | vila velha
# Processing Record 2 of Set 13 | limbang
# Processing Record 3 of Set 13 | ahome
# Processing Record 4 of Set 13 | shahr-e babak
# Processing Record 5 of Set 13 | kuznechnoye
# Processing Record 6 of Set 13 | semnan
# Processing Record 7 of Set 13 | kirkwall
# Processing Record 8 of Set 13 | kangaatsiaq
# Processing Record 9 of Set 13 | winnipeg
# Processing Record 10 of Set 13 | mazagao
# Processing Record 11 of Set 13 | pemangkat
# Processing Record 12 of Set 13 | tweed
# Processing Record 13 of Set 13 | fond du lac
# Processing Record 14 of Set 13 | jacareacanga
# Processing Record 15 of Set 13 | high level
# Processing Record 16 of Set 13 | poya
# Processing Record 17 of Set 13 | pozega
# Processing Record 18 of Set 13 | portland
# Processing Record 19 of Set 13 | launceston
# Processing Record 20 of Set 13 | yumen
# Processing Record 21 of Set 13 | bansko
# Processing Record 22 of Set 13 | leningradskiy
# Processing Record 23 of Set 13 | birobidzhan
# Processing Record 24 of Set 13 | gorontalo
# Processing Record 25 of Set 13 | karatau
# Processing Record 26 of Set 13 | coquimbo
# Processing Record 27 of Set 13 | porto velho
# -----------------------------
# Data Retrieval Complete
# ---------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#        City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Terrace  54.5163 -128.6035     66.11        77          75       21.85
# 1     Zabid  14.1951   43.3152     87.51        51         100       13.27
# 2    Faanui -16.4833 -151.7500     79.03        70          24       10.29
# 3     Kapaa  22.0752 -159.3190     82.72        75          90        5.01
# 4  Khatanga  71.9667  102.5000     57.31        45          57        9.42
# 5   Russell  32.3502  -85.1999     88.79        59          75        4.61
# 6    Lorain  41.3334  -82.1499     85.19        43           1        4.61
# 7     Bluff -46.6000  168.3333     38.80        86          74        7.20
# 8    Kovdor  67.5662   30.4758     51.98        75         100        5.37
# 9      Hilo  19.7297 -155.0900     80.80        81          90        5.75
#
#   Country Current Description
# 0      CA          light rain
# 1      YE     overcast clouds
# 2      PF          few clouds
# 3      US          light rain
# 4      RU       broken clouds
# 5      US       broken clouds
# 6      US           clear sky
# 7      NZ       broken clouds
# 8      RU     overcast clouds
# 9      US          light rain

# %%
new_column_order = ["City", "Country", "Lat", "Lng","Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_new_df=city_data_df[new_column_order]
city_data_new_df.head(10)
# Out:
#        City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Terrace      CA  54.5163 -128.6035     66.11        77          75
# 1     Zabid      YE  14.1951   43.3152     87.51        51         100
# 2    Faanui      PF -16.4833 -151.7500     79.03        70          24
# 3     Kapaa      US  22.0752 -159.3190     82.72        75          90
# 4  Khatanga      RU  71.9667  102.5000     57.31        45          57
# 5   Russell      US  32.3502  -85.1999     88.79        59          75
# 6    Lorain      US  41.3334  -82.1499     85.19        43           1
# 7     Bluff      NZ -46.6000  168.3333     38.80        86          74
# 8    Kovdor      RU  67.5662   30.4758     51.98        75         100
# 9      Hilo      US  19.7297 -155.0900     80.80        81          90
#
#    Wind Speed Current Description
# 0       21.85          light rain
# 1       13.27     overcast clouds
# 2       10.29          few clouds
# 3        5.01          light rain
# 4        9.42       broken clouds
# 5        4.61       broken clouds
# 6        4.61           clear sky
# 7        7.20       broken clouds
# 8        5.37     overcast clouds
# 9        5.75          light rain

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/cities.csv"
# Export the City_Data into a CSV.
city_data_new_df.to_csv(output_data_file, index_label="City_ID")
